# %%
# Import modules
import sys
import os
import pandas as pd
from pycaret.classification import *

# %%
## Check modules version
print('Notebook running from:',sys.executable)
print('Pandas:',pd.__version__)
# Out:
# Notebook running from: /home/naneen/Documents/DataScience/Projects/FinHack_LT_AV/py3-finhack/bin/python3
# Pandas: 1.2.1

# %%
## List data-raw
path_pwd = os.getcwd()
path_data_train = path_pwd+'/'+'data_raw/Train/' 
os.listdir(path_data_train)
# Out:
# ['train_bureau.xlsx', 'data_dict.xlsx', '.DS_Store', 'train_Data.xlsx']

# %%
## Set trainig data files
file_customer_train = path_data_train+'train_Data.xlsx'
print('Customer file:', file_customer_train)
# Out:
# Customer file: /home/naneen/Documents/DataScience/Projects/FinHack_LT_AV/data_raw/Train/train_Data.xlsx

# %%
## Load customer trainig data
df_customer = pd.read_excel(file_customer_train)
df_customer.head()
# Out:
#    ID Frequency InstlmentMode LoanStatus   PaymentMode  BranchID      Area  \
# 0   1   Monthly        Arrear     Closed         PDC_E         1       NaN
# 1   2   Monthly       Advance     Closed           PDC       333    BHOPAL
# 2   3   Quatrly        Arrear     Active  Direct Debit         1       NaN
# 3   7   Monthly       Advance     Closed        Billed       125      GUNA
# 4   8   Monthly        Arrear     Closed        Billed       152  BILASPUR
#
#    Tenure  AssetCost  AmountFinance  DisbursalAmount      EMI DisbursalDate  \
# 0      48     450000       275000.0         275000.0  24000.0    2012-02-10
# 1      47     485000       350000.0         350000.0  10500.0    2012-03-31
# 2      68     690000       519728.0         519728.0  38300.0    2017-06-17
# 3      48     480000       400000.0         400000.0  11600.0    2013-11-29
# 4      44     619265       440000.0         440000.0  15000.0    2011-12-08
#
#   MaturityDAte   AuthDate   AssetID  ManufacturerID  SupplierID    LTV SEX  \
# 0   2016-01-15 2012-02-10   4022465            1568       21946  61.11   M
# 1   2016-02-15 2012-03-31   4681175            1062       34802  70.00   M
# 2   2023-02-10 2017-06-17  25328146            1060      127335  69.77   M
# 3   2017-11-10 2013-11-29  13021591            1060       25094  80.92   M
# 4   2015-07-05 2011-12-08   3291320            1046       21853  71.05   M
#
#     AGE  MonthlyIncome         City           State   ZiPCODE  \
# 0  49.0       35833.33       RAISEN  MADHYA PRADESH  464993.0
# 1  23.0         666.67       SEHORE  MADHYA PRADESH  466001.0
# 2  39.0       45257.00       BHOPAL  MADHYA PRADESH  462030.0
# 3  24.0       20833.33  ASHOK NAGAR  MADHYA PRADESH  473335.0
# 4  56.0       27313.67     BILASPUR     CHATTISGARH  495442.0
#
#         Top-up Month
# 0        > 48 Months
# 1  No Top-up Service
# 2       12-18 Months
# 3        > 48 Months
# 4       36-48 Months

# %%
# Shape as data loaded
df_customer = df_customer.dropna()
df_customer.shape
# Out:
# (107126, 26)

# %%
# Organize data
data = df_customer.sample(frac=0.90, random_state=786)
data_unseen = df_customer.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (96413, 26)
# Unseen Data For Predictions: (10713, 26)

# %% [markdown]
# ***

# %% [markdown]
# ## Setup

# %%
# Sub-set of data to test
nsubset = 96413
data = data.iloc[:nsubset,:]
data.shape
# Out:
# (96413, 26)

# %%
# list of attributes to consider
list_attributes = ['ID','Frequency', 'InstlmentMode', 'LoanStatus', 'PaymentMode', 'Tenure', 'AssetCost', 'AmountFinance', 'DisbursalAmount', 'EMI', 'DisbursalDate', 'MaturityDAte', 'AuthDate', 'LTV', 'SEX', 'AGE', 'MonthlyIncome','Top-up Month']

# %%
# Divide data into data_features and data_target
data = data[list_attributes]

# %%
data.shape
# Out:
# (96413, 18)

# %%
## Setup
mclf = setup(data = data, target = 'Top-up Month', session_id=123, experiment_name='FinHack1')
# Out:
# <style  type="text/css" >
# </style><table id="T_bfae9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bfae9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bfae9_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_bfae9_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bfae9_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_bfae9_row1_col1" class="data row1 col1" >Top-up Month</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bfae9_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_bfae9_row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_bfae9_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_bfae9_row3_col1" class="data row3 col1" > > 48 Months: 0, 12-18 Months: 1, 18-24 Months: 2, 24-30 Months: 3, 30-36 Months: 4, 36-48 Months: 5, No Top-up Service: 6</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_bfae9_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_bfae9_row4_col1" class="data row4 col1" >(96413, 18)</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_bfae9_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_bfae9_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_bfae9_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_bfae9_row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_bfae9_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_bfae9_row7_col1" class="data row7 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_bfae9_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_bfae9_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_bfae9_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_bfae9_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_bfae9_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_bfae9_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_bfae9_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_bfae9_row11_col1" class="data row11 col1" >(67489, 77)</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_bfae9_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_bfae9_row12_col1" class="data row12 col1" >(28924, 77)</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_bfae9_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_bfae9_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_bfae9_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_bfae9_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_bfae9_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_bfae9_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_bfae9_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_bfae9_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_bfae9_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_bfae9_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_bfae9_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_bfae9_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_bfae9_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_bfae9_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_bfae9_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_bfae9_row20_col1" class="data row20 col1" >FinHack1</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_bfae9_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_bfae9_row21_col1" class="data row21 col1" >271e</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_bfae9_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_bfae9_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_bfae9_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_bfae9_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_bfae9_level0_

# %%
# Available models for multilevel classification
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp           pycaret.internal.tunable.TunableMLPClassifier  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True

# %%
# Identify the best model - Run overnight
#best_model = compare_models()

# %% [markdown]
# ***

# %% [markdown]
# ## Model

# %%
# Create model
model = create_model('ada', fold=2)
# Out:
# <style  type="text/css" >
# #T_ed88d_row2_col0,#T_ed88d_row2_col1,#T_ed88d_row2_col2,#T_ed88d_row2_col3,#T_ed88d_row2_col4,#T_ed88d_row2_col5,#T_ed88d_row2_col6{
#             background:  yellow;
#         }</style><table id="T_ed88d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ed88d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ed88d_row0_col0" class="data row0 col0" >0.8192</td>
#                         <td id="T_ed88d_row0_col1" class="data row0 col1" >0.6166</td>
#                         <td id="T_ed88d_row0_col2" class="data row0 col2" >0.1431</td>
#                         <td id="T_ed88d_row0_col3" class="data row0 col3" >0.6875</td>
#                         <td id="T_ed88d_row0_col4" class="data row0 col4" >0.7395</td>
#                         <td id="T_ed88d_row0_col5" class="data row0 col5" >0.0000</td>
#                         <td id="T_ed88d_row0_col6" class="data row0 col6" >0.0002</td>
#             </tr>
#             <tr>
#                         <th id="T_ed88d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ed88d_row1_col0" class="data row1 col0" >0.8193</td>
#                         <td id="T_ed88d_row1_col1" class="data row1 col1" >0.6192</td>
#                         <td id="T_ed88d_row1_col2" class="data row1 col2" >0.1428</td>
#                         <td id="T_ed88d_row1_col3" class="data row1 col3" >0.6786</td>
#                         <td id="T_ed88d_row1_col4" class="data row1 col4" >0.7393</td>
#                         <td id="T_ed88d_row1_col5" class="data row1 col5" >-0.0009</td>
#                         <td id="T_ed88d_row1_col6" class="data row1 col6" >-0.0049</td>
#             </tr>
#             <tr>
#                         <th id="T_ed88d_level0_row2" class="row_heading level0 row2" >Mean</th>
#                         <td id="T_ed88d_row2_col0" class="data row2 col0" >0.8192</td>
#                         <td id="T_ed88d_row2_col1" class="data row2 col1" >0.6179</td>
#                         <td id="T_ed88d_row2_col2" class="data row2 col2" >0.1429</td>
#                         <td id="T_ed88d_row2_col3" class="data row2 col3" >0.6831</td>
#                         <td id="T_ed88d_row2_col4" class="data row2 col4" >0.7394</td>
#                         <td id="T_ed88d_row2_col5" class="data row2 col5" >-0.0004</td>
#                         <td id="T_ed88d_row2_col6" class="data row2 col6" >-0.0024</td>
#             </tr>
#             <tr>
#                         <th id="T_ed88d_level0_row3" class="row_heading level0 row3" >SD</th>
#                         <td id="T_ed88d_row3_col0" class="data row3 col0" >0.0000</td>
#                         <td id="T_ed88d_row3_col1" class="data row3 col1" >0.0013</td>
#                         <td id="T_ed88d_row3_col2" class="data row3 col2" >0.0001</td>
#                         <td id="T_ed88d_row3_col3" class="data row3 col3" >0.0045</td>
#                         <td id="T_ed88d_row3_col4" class="data row3 col4" >0.0001</td>
#                         <td id="T_ed88d_row3_col5" class="data row3 col5" >0.0005</td>
#                         <td id="T_ed88d_row3_col6" class="data row3 col6" >0.0026</td>
#             </tr>
#     </tbody></table>

# %%
# hyper-param tuning
tuned_model = tune_model(model, fold=2)
# Out:
# <style  type="text/css" >
# #T_6df9c_row2_col0,#T_6df9c_row2_col1,#T_6df9c_row2_col2,#T_6df9c_row2_col3,#T_6df9c_row2_col4,#T_6df9c_row2_col5,#T_6df9c_row2_col6{
#             background:  yellow;
#         }</style><table id="T_6df9c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6df9c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6df9c_row0_col0" class="data row0 col0" >0.8207</td>
#                         <td id="T_6df9c_row0_col1" class="data row0 col1" >0.5894</td>
#                         <td id="T_6df9c_row0_col2" class="data row0 col2" >0.1429</td>
#                         <td id="T_6df9c_row0_col3" class="data row0 col3" >0.6735</td>
#                         <td id="T_6df9c_row0_col4" class="data row0 col4" >0.7399</td>
#                         <td id="T_6df9c_row0_col5" class="data row0 col5" >0.0000</td>
#                         <td id="T_6df9c_row0_col6" class="data row0 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6df9c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6df9c_row1_col0" class="data row1 col0" >0.8207</td>
#                         <td id="T_6df9c_row1_col1" class="data row1 col1" >0.6001</td>
#                         <td id="T_6df9c_row1_col2" class="data row1 col2" >0.1429</td>
#                         <td id="T_6df9c_row1_col3" class="data row1 col3" >0.6735</td>
#                         <td id="T_6df9c_row1_col4" class="data row1 col4" >0.7398</td>
#                         <td id="T_6df9c_row1_col5" class="data row1 col5" >0.0000</td>
#                         <td id="T_6df9c_row1_col6" class="data row1 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6df9c_level0_row2" class="row_heading level0 row2" >Mean</th>
#                         <td id="T_6df9c_row2_col0" class="data row2 col0" >0.8207</td>
#                         <td id="T_6df9c_row2_col1" class="data row2 col1" >0.5948</td>
#                         <td id="T_6df9c_row2_col2" class="data row2 col2" >0.1429</td>
#                         <td id="T_6df9c_row2_col3" class="data row2 col3" >0.6735</td>
#                         <td id="T_6df9c_row2_col4" class="data row2 col4" >0.7399</td>
#                         <td id="T_6df9c_row2_col5" class="data row2 col5" >0.0000</td>
#                         <td id="T_6df9c_row2_col6" class="data row2 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_6df9c_level0_row3" class="row_heading level0 row3" >SD</th>
#                         <td id="T_6df9c_row3_col0" class="data row3 col0" >0.0000</td>
#                         <td id="T_6df9c_row3_col1" class="data row3 col1" >0.0053</td>
#                         <td id="T_6df9c_row3_col2" class="data row3 col2" >0.0000</td>
#                         <td id="T_6df9c_row3_col3" class="data row3 col3" >0.0000</td>
#                         <td id="T_6df9c_row3_col4" class="data row3 col4" >0.0000</td>
#                         <td id="T_6df9c_row3_col5" class="data row3 col5" >0.0000</td>
#                         <td id="T_6df9c_row3_col6" class="data row3 col6" >0.0000</td>
#             </tr>
#     </tbody></table>

# %%
plot_model(tuned_model, plot='auc')

# %%
# Finalize the model 
final_model = finalize_model(tuned_model)
print(final_model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                    learning_rate=0.092, n_estimators=10, random_state=123)

# %% [markdown]
# ***

# %% [markdown]
# ## Save Model

# %%
# model_name (INPUT)
model_name = 'ada'

# model_save_name
model_save_name  = model_name+'_'+str(nsubset)

# SAve model 
save_model(final_model, model_save_name)
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='Top-up Month',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_...
#                  ('dummy', Dummify(target='Top-up Month')),
#                  ('fix_perfect', Remove_100(target='Top-up Month')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                                      learning_rate=0.092, n_estimators=10,
#                                      random_state=123)]],
#           verbose=False),
#  'ada_35000.pkl')

# %% [markdown]
# ***

# %% [markdown]
# ## Re-load Model

# %%
# Load saved model 
saved_model = load_model(model_save_name)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
unseen_predictions = predict_model(saved_model, data=data_unseen)
unseen_predictions.head()
# Out:
#     ID Frequency InstlmentMode LoanStatus PaymentMode  BranchID      Area  \
# 0   11   Monthly        Arrear     Closed       PDC_E         5    RAIPUR
# 1   12   Monthly        Arrear     Closed         PDC         5    RAIPUR
# 2   19   Quatrly        Arrear     Closed       PDC_E       152  BILASPUR
# 3   22   Monthly        Arrear     Closed      Billed       152  BILASPUR
# 4  109   Quatrly        Arrear     Closed       PDC_E       194   CUTTACK
#
#    Tenure  AssetCost  AmountFinance  ...    LTV  SEX   AGE MonthlyIncome  \
# 0      48     600000       360000.0  ...  60.00    M  41.0      46195.08
# 1      46     539275       400000.0  ...  74.17    M  51.0      15000.00
# 2      36     507265       360000.0  ...  70.97    M  58.0      17000.00
# 3      33     354000       290000.0  ...  81.92    M  27.0     290000.00
# 4      48     600000       436000.0  ...  72.67    M  46.0      25000.00
#
#        City        State   ZiPCODE       Top-up Month              Label  \
# 0    RAIPUR  CHATTISGARH  493114.0  No Top-up Service  No Top-up Service
# 1    RAIPUR  CHATTISGARH  493196.0  No Top-up Service  No Top-up Service
# 2  BILASPUR  CHATTISGARH  495001.0  No Top-up Service  No Top-up Service
# 3  BILASPUR  CHATTISGARH  495224.0  No Top-up Service  No Top-up Service
# 4      GAYA        BIHAR  823001.0  No Top-up Service  No Top-up Service
#
#     Score
# 0  0.6584
# 1  0.6584
# 2  0.6584
# 3  0.6835
# 4  0.6584
#
# [5 rows x 28 columns]

# %%
from pycaret.utils import check_metric
check_metric(data_unseen['Top-up Month'], unseen_predictions['Label'], metric = 'Accuracy')
# Out:
# 0.8199

# %% [markdown]
# ***

# %%
### Training data from Hackthon
file_customer_test = 'data_raw/test_Data.xlsx'

# %%
df_customer_test = pd.read_excel(file_customer_test)
df_customer_test.shape
# Out:
# (14745, 25)

# %%
list_attributes2 = ['ID','Frequency', 'InstlmentMode', 'LoanStatus', 'PaymentMode', 'Tenure', 'AssetCost', 'AmountFinance', 'DisbursalAmount', 'EMI', 'DisbursalDate', 'MaturityDAte', 'AuthDate', 'LTV', 'SEX', 'AGE', 'MonthlyIncome']

# %%
data_unseen2 = df_customer_test[list_attributes2]
data_unseen2.shape
# Out:
# (14745, 17)

# %%
unseen_predictions2 = predict_model(final_model, data=data_unseen2)
unseen_predictions2.head()
# Out:
#     ID    Frequency InstlmentMode LoanStatus PaymentMode  Tenure  AssetCost  \
# 0    4      Monthly       Advance     Closed       PDC_E      46     480000
# 1    5      Monthly       Advance     Closed         PDC      45     480000
# 2    6      Quatrly        Arrear     Closed         PDC      48     580000
# 3   25  Half Yearly        Arrear     Closed      Billed      36     725000
# 4  119      Quatrly        Arrear     Closed         PDC      48     617000
#
#    AmountFinance  DisbursalAmount      EMI DisbursalDate MaturityDAte  \
# 0       365000.0         365000.0   1000.0    2011-12-29   2015-10-05
# 1       285000.0         285000.0   9300.0    2012-04-28   2016-01-01
# 2       400000.0         400000.0  35800.0    2013-10-22   2017-09-10
# 3       500000.0         500000.0  52000.0    2013-05-21   2016-02-10
# 4       400000.0         400000.0  35400.0    2012-11-30   2016-12-05
#
#     AuthDate    LTV SEX   AGE  MonthlyIncome              Label   Score
# 0 2011-12-29  75.83   M  50.0       32069.00  No Top-up Service  0.6584
# 1 2012-04-28  57.44   M  35.0       25000.00  No Top-up Service  0.6584
# 2 2013-10-22  68.97   M  37.0       23333.33  No Top-up Service  0.6584
# 3 2013-05-21  61.79   M  55.0       91666.67  No Top-up Service  0.6835
# 4 2012-11-30  59.09   M  48.0       12500.00  No Top-up Service  0.6584

# %%
unseen_predictions2['Label'].value_counts()
# Out:
# No Top-up Service    14745
# Name: Label, dtype: int64

# %%
save_submission = unseen_predictions2[['ID','Label']]
save_submission.rename(columns={'Label':'Top-up Month'}, inplace=True)
save_submission.head()
# Out:
#     ID       Top-up Month
# 0    4  No Top-up Service
# 1    5  No Top-up Service
# 2    6  No Top-up Service
# 3   25  No Top-up Service
# 4  119  No Top-up Service

# %%
save_submission.to_csv(model_save_name+'.csv', index=False)
